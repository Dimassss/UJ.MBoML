# %% [markdown]
# # Task 1.
# Generate data as below. Then fit linear and polynomial regressions of degree 3 and 17.
# Draw the data and all three curves on one figure.
# Next fit polynomial ridge regression (degree 17) with lambda equal 1 and 100 (in the penalty function take into account all coeaficionts).
#
# Compare the new curves on the graph with a polynomial regression of degree 17.

# %%
import numpy as np
x=np.linspace(0,2*np.pi,40)
y=np.sin(x)+np.random.normal(0,0.4,40)
import matplotlib.pyplot as plt

plt.scatter(x,y)
plt.show()
import sklearn.linear_model as lm
#lub
#form sklearn.linear_model import LinearRegression
#form sklearn.linear_model import Ridge
# do ridge regression

import sklearn.preprocessing as pr

# %%
# Out:
# 0.7405322690969932

# %% [markdown]
# # Task 2
#
# Using Normal Equaiton for Ridge regression ($(X^TX+\lambda I)\beta=X^Ty$) calculate the coefficients from Task 1.

# %% [markdown]
# # Task 3.
#
# Generate data as below.
# Then train (on the whole dataset) two logistic regression where predictors are
# * X[:,:1], X[:,1:2]
# * X[:,1:2] and all powers up to degree 4 of X[:,:1].
#
# Next fit logistic regression with penalty function from $l^2$ and lambda equal 1 and 10 (C=?).
# Draw the data and this four boundary curves on one figure.
#
# Show confussion matrices for the above models.

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import classification_report, confusion_matrix

N=30

df1 =5*pd.DataFrame(np.random.randn(N, 3), columns=['A', 'B','C'])
df2 =10+10*pd.DataFrame(np.random.randn(N, 3), columns=['A', 'B','C'])

Data=np.concatenate((df1, df2), axis=0)
Data[:,2]=1
Data[0:N,2]=0


import matplotlib.pyplot as plt

s='b'*N+'r'*N
plt.scatter(Data[:,0],Data[:,1], s=5,alpha=1,c=list(s))
plt.show()

# %%
# Out:
#               precision    recall  f1-score   support
#
#      class 0       0.85      0.93      0.89        30
#      class 1       0.93      0.83      0.88        30
#
#     accuracy                           0.88        60
#    macro avg       0.89      0.88      0.88        60
# weighted avg       0.89      0.88      0.88        60
#
# [[28  2]
#  [ 5 25]]
#               precision    recall  f1-score   support
#
#      class 0       0.88      0.97      0.92        30
#      class 1       0.96      0.87      0.91        30
#
#     accuracy                           0.92        60
#    macro avg       0.92      0.92      0.92        60
# weighted avg       0.92      0.92      0.92        60
#
# [[29  1]
#  [ 4 26]]
#               precision    recall  f1-score   support
#
#      class 0       0.82      0.60      0.69        30
#      class 1       0.68      0.87      0.76        30
#
#     accuracy                           0.73        60
# ...

# %% [markdown]
# # Task 4
# Split the Iris dataset into test and training sets.
# Fit the logistic model without and with regularizaion(try to find the best parameters) on the Iris dataset.
# Draw the data and this boundary curves on one figure. Compare the corresponding confusion matrices (calculated on the test set).

# %%
import pandas as pd
from sklearn.metrics import classification_report, confusion_matrix
from sklearn import datasets
import matplotlib.pyplot as plt

# import some data to play with
iris = datasets.load_iris()
X = iris.data[:, :2]  # we only take the first two features.
y = iris.target
plt.scatter(X[:, 0], X[:, 1], c=y)
plt.show()

# %%
### rozwiazanie
# Out:
#               precision    recall  f1-score   support
#
#      class 0       1.00      1.00      1.00        50
#      class 1       0.75      0.76      0.75        50
#      class 2       0.76      0.74      0.75        50
#
#     accuracy                           0.83       150
#    macro avg       0.83      0.83      0.83       150
# weighted avg       0.83      0.83      0.83       150
#
# [[50  0  0]
#  [ 0 38 12]
#  [ 0 13 37]]
#               precision    recall  f1-score   support
#
#      class 0       0.98      1.00      0.99        50
#      class 1       0.73      0.70      0.71        50
#      class 2       0.73      0.74      0.73        50
#
#     accuracy                           0.81       150
#    macro avg       0.81      0.81      0.81       150
# weighted avg       0.81      0.81      0.81       150
#
# [[50  0  0]
#  [ 1 35 14]
#  [ 0 13 37]]

# %% [markdown]
# # Task 5
# Repeat Task 4, but use cross-validation for finding the best parameters (use only the training set). Compare the corresponding confusion matrices (calculated on the test set).

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import KFold
from sklearn import linear_model
import numpy as np

# %%
from sklearn.datasets import load_iris
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV
